# %% [markdown]
# # Using Commonsense and ConceptNet
#
# This is a WIP

# %%
import commonsense.conceptnet as kb
from commonsense.logical_classes import to_data_frame

cn = kb.ConceptNet()

facts = cn.search_all("fruit")
facts
# Out:
# [Fact(subject='apple', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='a fruit', predicate='UsedFor', object='eating', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='HasProperty', object='good for you', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='IsA', object='a good source of vitamins', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='HasProperty', object='good for health', reason=None, score=1.0, count=1),
#  Fact(subject='pineapple', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='ReceivesAction', object='eaten', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='AtLocation', object='a tree', reason=None, score=1.0, count=1),
#  Fact(subject='a fruit', predicate='AtLocation', object='a market', reason=None, score=1.0, count=1),
#  Fact(subject='grape', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='produce', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='orange', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='lemon', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='lime', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='a mango', predicate='IsA', object='a fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='IsA', object='a better snack than candy', reason=None, score=1.0, count=1),
#  Fact(subject='plums', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='watermelon', predicate='IsA', object='a fruit', reason=None, score=1.0, count=1),
#  Fact(subject='raspberry', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='peach', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='seed', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='membuahkan', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='pome', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='frutto', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='plod', reason=None, score=1.0, count=1),
#  Fact(subject='ทำให้ออกลูก', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='産物', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='効果', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='結', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='wine', predicate='MadeOf', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='frutta', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='実', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='berry', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='skin', predicate='AtLocation', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='some fruit', predicate='HasProperty', object='sour', reason=None, score=1.0, count=1),
#  Fact(subject='hedelmä', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='frutë', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='IsA', object='reproductive structure', reason=None, score=1.0, count=1),
#  Fact(subject='juniper berry', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='frutë', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruto', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='賜物', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='IsA', object='reproductive structure', reason=None, score=1.0, count=1),
#  Fact(subject='frutta', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='berry', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='実', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='産物', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='pome', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='結', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='yield', reason=None, score=1.0, count=1),
#  Fact(subject='skin', predicate='AtLocation', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='prodotto', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='some fruit', predicate='HasProperty', object='sour', reason=None, score=1.0, count=1),
#  Fact(subject='hedelmä', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='seed', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='plodina', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='saada tuottamaan hedelmää', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruitu', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='voće', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='hagberry', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='結晶', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='ผล', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='ทำให้ออกลูก', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='plod', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='frutë', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruto', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='賜物', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='yield', reason=None, score=1.0, count=1),
#  Fact(subject='hedelmä', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='tulos', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='juniper berry', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='IsA', object='another name for homosexual', reason=None, score=1.0, count=1),
#  Fact(subject='frukt', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='IsA', object='reproductive structure', reason=None, score=1.0, count=1),
#  Fact(subject='frutta', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='berry', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='産物', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='効果', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='membuahkan', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='frutto', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='prodotto', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='some fruit', predicate='HasProperty', object='sour', reason=None, score=1.0, count=1),
#  Fact(subject='frutë', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='MannerOf', object='bear', reason=None, score=1.0, count=1),
#  Fact(subject='plodina', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='saada tuottamaan hedelmää', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='実', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruitu', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='果物', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='owoc', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='acorn', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='yemiş', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='IsA', object='an important food group', reason=None, score=1.0, count=1),
#  Fact(subject='frukt', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='ثَمَرَة', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Causes', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='drupe', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='may apple', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='buah', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='tulos', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='hedelmöidä', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='菓物', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='結実', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='keuntungan', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruitu eman', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='ผล', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='ผลไม้', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruta', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='voćni', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='cubeb', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='HasA', object='sugar', reason=None, score=1.0, count=1),
#  Fact(subject='owoc', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='buah', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='marasca', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='seeds', predicate='AtLocation', object='a fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='IsA', object='an important food group', reason=None, score=1.0, count=1),
#  Fact(subject='子', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='ออกลูก', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='水物', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='ลูก', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='rod', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='結實', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='効果', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='frutta', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='frutë', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='berry', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='tulos', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruto', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='木の実', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='yield', reason=None, score=1.0, count=1),
#  Fact(subject='juniper berry', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='hedelmä', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='IsA', object='reproductive structure', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='IsA', object='another name for homosexual', reason=None, score=1.0, count=1),
#  Fact(subject='ทำให้ออกลูก', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='plod', reason=None, score=1.0, count=1),
#  Fact(subject='効果', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='賜物', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='IsA', object='an important food group', reason=None, score=1.0, count=1),
#  Fact(subject='skin', predicate='AtLocation', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='prodotto', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='some fruit', predicate='HasProperty', object='sour', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='MannerOf', object='bear', reason=None, score=1.0, count=1),
#  Fact(subject='seed', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruto', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='IsA', object='a good snack', reason=None, score=1.0, count=1),
#  Fact(subject='frukt', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='yield', reason=None, score=1.0, count=1),
#  Fact(subject='賜物', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='membuahkan', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='acorn', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='yemiş', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='voće', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='kantaa hedelmää', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Causes', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='ثَمَرَة', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='hagberry', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='結晶', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='たま物', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruitu', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='hedelmöidä', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='tulos', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='keuntungan', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruits', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruta', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='risultato', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='chokecherry', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='pear', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='cherry', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='berry', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='preserve', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='juice', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='tomato', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='果实', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='plum', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='date', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='pineapple', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='peel', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='banana', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='cranberry', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='apricot', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='eleme fig', predicate='HasContext', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='lemma', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='multifruit', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='multiple fruit', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='chinotto', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='highbush blueberry', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='פירות', reason=None, score=1.0, count=1),
#  Fact(subject='kiwi berry', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='a fruit', predicate='UsedFor', object='eat', reason=None, score=1.0, count=1),
#  Fact(subject='allegagione', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='abildgård', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruitlet', predicate='DerivedFrom', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='maleic acid', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='a fruit', predicate='AtLocation', object='a gay bar', reason=None, score=1.0, count=1),
#  Fact(subject='frutta', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fried pie', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='frut', reason=None, score=1.0, count=1),
#  Fact(subject='mamoncillo', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='ogeechee lime', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fructify', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='фруктовый', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='konfijt', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='hua ʻai', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='ovocie', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject="nature's candy", predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='пхъэшъхьэмышъхь', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='blackberry', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='cloudberry', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='ཤིང ཏོག', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='ผล', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruita', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='AtLocation', object='the refrigerator', reason=None, score=1.0, count=1),
#  Fact(subject='gröönhökerin', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='結晶', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='gröönhökerin', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='結晶', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruitage', predicate='DerivedFrom', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='snow pear', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject="nature's candy", predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='wæstm', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='a tree', predicate='UsedFor', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='vaisius', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='ผล', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='konfijt', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='kamatis', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit bowl', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='плодовый', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='mamoncillo', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='poma', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='powidło', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='脂膏', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='frutta', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='froktu', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='مېۋە', reason=None, score=1.0, count=1),
#  Fact(subject='augļkopība', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='calabash', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='hip', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='جب', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='carpolite', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='xochicualli', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fêkî', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='ortoflorofrutticoltore', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='cape gooseberry', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='dragon tree', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='spiceberry', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='oranĝo', predicate='HasContext', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='palmvrucht', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='eleme fig', predicate='HasContext', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='lugnas', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='نبق', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='white gourd', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='prutas', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='mêwe', reason=None, score=1.0, count=1),
#  Fact(subject='acanthocarpous', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='polycarpic', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='aniseed', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='rvát', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='tamatis', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='жимслэг', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='konfyt', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='cumball', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='ooftbouw', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='ortofrutticoltrice', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruttifero', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='ruruy', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='avocado pear', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='gur cake', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='ovoce', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='frugivorous', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='woody pear', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='uva', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='తొన', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='плод', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='apple', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='плод', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='apple', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='a fruit', predicate='AtLocation', object='a fruit cocktail', reason=None, score=1.0, count=1),
#  Fact(subject='జామపండు', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='과일', reason=None, score=1.0, count=1),
#  Fact(subject='rote grütze', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruity', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='stone', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='cobbler', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='tomato', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='blueberry', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='a fruit', predicate='UsedFor', object='garnish', reason=None, score=1.0, count=1),
#  Fact(subject='gröönhökersche', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='stoneseed', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='cobnut', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='regreen', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='frit', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='frutto di bosco', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='rugelach', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='pulp', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='生果', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='frukt', reason=None, score=1.0, count=1),
#  Fact(subject='bilimbi', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='sloe', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='🍒', predicate='SymbolOf', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='plod', reason=None, score=1.0, count=1),
#  Fact(subject='cotton boll', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='unfruited', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruitwood', predicate='DerivedFrom', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='ngaita', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='monte cristo sandwich', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='𒄒', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='ortofrutticolo', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='pomegranate', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='tuna', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='плод', reason=None, score=1.0, count=1),
#  Fact(subject='scrump', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='guavaberry', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='frutticoltore', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='skin', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='λεμόνι', predicate='HasContext', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='watermelon', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='IsA', object='best when ripe', reason=None, score=1.0, count=1),
#  Fact(subject='clarnus', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='caro', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='macadamia', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='star apple', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='cynnyrch', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruttificare', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='దొండపండు', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='gorp', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='applecart', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='pancarpineus', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='плід', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='greengrocer', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='mcintosh apple', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='απίδι', predicate='HasContext', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='hypocist', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='chutney', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='ຫມາກຜົນ', reason=None, score=1.0, count=1),
#  Fact(subject='schlaube', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='guarriboom', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='پھل', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='ܛܘܒܐ', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='zieleniak', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='糖葫蘆', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='poamã', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='datle', predicate='HasContext', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='фрукт', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='sadež', reason=None, score=1.0, count=1),
#  Fact(subject='ripe fruit', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='sweetie', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='frukto', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='muyu', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='cynnyrch', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruttificare', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='sad', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='simple fruit', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='kabog', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='zuccata', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit drop', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='IsA', object='external anatomical part', reason=None, score=1.0, count=1),
#  Fact(subject='osoberry', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='granny smith apple', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='skin', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='frukto', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='ǃʻàa ǃʻàa sè', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='फल', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='datil', predicate='HasContext', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='snap bean', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruitless', predicate='DerivedFrom', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='sloe', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='🍈', predicate='SymbolOf', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='blædnes', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='liber', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fructiculose', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='tayberry', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='buckmast', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='жеміс', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='miwe', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='粃', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='vrucht', reason=None, score=1.0, count=1),
#  Fact(subject='tayberry', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='生鮮', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='miwe', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='frog eye salad', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='paso', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fvh', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fryt', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='ismu', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='spotted dick', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='pomme', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='superfruit', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='smoothify', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='bloom', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='meyve', reason=None, score=1.0, count=1),
#  Fact(subject='ibyok', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='frut', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='voce', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='果實', reason=None, score=1.0, count=1),
#  Fact(subject='gröönhöker', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='ké chí', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='spotted dick', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='icebox pie', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='HasA', object='a pleasant taste', reason=None, score=1.0, count=1),
#  Fact(subject='panna cotta', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='cankerworm', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='sad', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='da cam', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='stoneweed', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='ungol', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='top fruit', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='液果', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='marasca', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='phalsa', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='RelatedTo', object='disadvantageous', reason=None, score=1.0, count=1),
#  Fact(subject='ooftbouw', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='cascola', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='keeper', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='HasA', object='antioxidants', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='RelatedTo', object='disadvantageous', reason=None, score=1.0, count=1),
#  Fact(subject='some fruit', predicate='ReceivesAction', object='composed of sections', reason=None, score=1.0, count=1),
#  Fact(subject='phalsa', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='florentine', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='bunga', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='blet', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='овошје', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='orange', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='keeper', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='บ๊วย', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='lancepod', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='frucht', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='frukto', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit juice', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='breadfruit', predicate='DerivedFrom', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='a fruit', predicate='UsedFor', object='consumption', reason=None, score=1.0, count=1),
#  Fact(subject='banana', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='polyachene', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='biferous', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='hesperidio', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='orange', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='keeper', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='sagbay luwag', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='yemiş', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit juice', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='caroço', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='breadfruit', predicate='DerivedFrom', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruitage', predicate='DerivedFrom', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='pome', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='овоцина', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='meyvə', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='loco', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='冰糖葫蘆', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fructescence', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='పూబిందె', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='fruges', reason=None, score=1.0, count=1),
#  Fact(subject='ⲕⲁⲣⲡⲟⲥ', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='palatha', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='pistachio', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='かじゅ', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='IsA', object='rarely', reason=None, score=1.0, count=1),
#  Fact(subject='結実', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='ὀπωροθήκη', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='tarnina', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='a fruit', predicate='IsA', object='a part of a plant', reason=None, score=1.0, count=1),
#  Fact(subject="beggar's lice", predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='плодовый', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='ExternalURL', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='फलफूल', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruict', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='pirozhki', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='chajá', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='hazelnut', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='พุทรา', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='orthospermous', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='IsA', object='a healthy food', reason=None, score=1.0, count=1),
#  Fact(subject='auglis', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='crudités', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='xocotl', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='canefruit', predicate='DerivedFrom', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='brierberry', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='مېۋە', reason=None, score=1.0, count=1),
#  Fact(subject='gyrogonite', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='sapal', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='ɗa', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='tuna', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='పూబిందె', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='follicle', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='حائل', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='ash gourd', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='eurycarpus', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruitlike', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='かじゅ', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
# ...
#  Fact(subject='مجهول', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='portokal', predicate='HasContext', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='iymis', reason=None, score=1.0, count=1),
#  Fact(subject='another way to say "fruit ."', predicate='IsA', object='"fruit"', reason=None, score=1.0, count=1),
#  Fact(subject='خريف', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='frutë', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='frugivore', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='mêwe', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='apricot', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='portokal', predicate='HasContext', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='κορόμηλο', predicate='HasContext', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='florentine', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='manchineel tree', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='shea', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fretg', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='حمر', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='peewah', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='果实', reason=None, score=1.0, count=1),
#  Fact(subject='fruiten', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='chööjüdüüjüdü', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='ફળ', reason=None, score=1.0, count=1),
#  Fact(subject='whitebark raspberry', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='vegetable', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='果实', reason=None, score=1.0, count=1),
#  Fact(subject='packhouse', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruiten', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='kaong', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='hedgeapple', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='crudités', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='かんか', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='oko', reason=None, score=1.0, count=1),
#  Fact(subject='chööjüdüüjüdü', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='pejibaye', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='whitebark raspberry', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='pannier', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='giú', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='canditura', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='walnut', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='banana', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='cocoa pod', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='ovocný', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='CapableOf', object='decay', reason=None, score=1.0, count=1),
#  Fact(subject='lolly ice', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='frouezh', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='ثمر', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='gooseberry', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='murunga', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='pannier', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='auglis', reason=None, score=1.0, count=1),
#  Fact(subject='pink lemonade', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='nonfruit', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='ଫଳ', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='walnut', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='ovocný', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='菓', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruitmonger', predicate='DerivedFrom', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='toothbill', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='raisins', predicate='IsA', object='a fruit', reason=None, score=1.0, count=1),
#  Fact(subject='ὀπώρα', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='white rot', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='mess', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='pepper', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='మామిడిపండు', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='pumpkin', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='pannier', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='walnut', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='مربى', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='aculeaticarpus', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='ovocný', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='massala', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='cocã', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='otoba fat', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='raisins', predicate='IsA', object='a fruit', reason=None, score=1.0, count=1),
#  Fact(subject='isiqhamo', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='ఫలించు', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='salalberry', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruiteth', predicate='FormOf', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='hop', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='青果', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='実', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='परिणाम', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='gröönhökersch', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='dambose', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='isiqhamo', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='IsA', object='living thing', reason=None, score=1.0, count=1),
#  Fact(subject='cotão', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='IsA', object='rarely', reason=None, score=1.0, count=1),
#  Fact(subject='結実', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='ܦܐܪܐ', reason=None, score=1.0, count=1),
#  Fact(subject='ὀπωροθήκη', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='ผลไม้', reason=None, score=1.0, count=1),
#  Fact(subject='ఫలించు', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='果實', reason=None, score=1.0, count=1),
#  Fact(subject='다래', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='мева', reason=None, score=1.0, count=1),
#  Fact(subject='καρποσ', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='タチバナ', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='ābols', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='ooftwijn', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='பழம்', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='果品', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='HasProperty', object='very good for our health', reason=None, score=1.0, count=1),
#  Fact(subject='mak', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='cranberry', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit juice', predicate='DerivedFrom', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='プルーン', predicate='HasContext', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='kart', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='costermonger', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='melanocarpus', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='papaya', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='פרוכט', reason=None, score=1.0, count=1),
#  Fact(subject='chestnut', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='UsedFor', object='make jelly', reason=None, score=1.0, count=1),
#  Fact(subject='fourth of july tomato', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='οπωρα', reason=None, score=1.0, count=1),
#  Fact(subject='pome', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='多汁果', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='lima', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='vắt', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='ExternalURL', object='201656273-v', reason=None, score=1.0, count=1),
#  Fact(subject='stenocarpus', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='frukto', reason=None, score=1.0, count=1),
#  Fact(subject='җимеш', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='tejocote', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='canefruit', predicate='DerivedFrom', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='plum curculio', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='фрукт', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruticulture', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='frutto', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='साल', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='gyrogonite', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='樹子', reason=None, score=1.0, count=1),
#  Fact(subject='african cherry orange', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='संतरा', predicate='HasContext', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='ఫలించు', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='brown sauce', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='achaenocarp', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='青果', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='akaĵuo', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='carp', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='IsA', object='portable object', reason=None, score=1.0, count=1),
#  Fact(subject='μούρο', predicate='HasContext', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='hag', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='puuvili', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='lecanorine', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='lychee', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='doum fruit', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='a banana', predicate='InstanceOf', object='a fruit', reason=None, score=1.0, count=1),
#  Fact(subject='eggplant', predicate='IsA', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='җимеш', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='frut', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='fruit', predicate='Synonym', object='פרי', reason=None, score=1.0, count=1),
#  Fact(subject='buah', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='သစ်သီးရည်', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='tendal', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='soursop', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='katmon', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='elderberry', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='🍊', predicate='SymbolOf', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='lanarkshire disease', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='vinify', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='պտուղ', predicate='Synonym', object='fruit', reason=None, score=1.0, count=1),
#  Fact(subject='hedelmähyytelö', predicate='RelatedTo', object='fruit', reason=None, score=1.0, count=1),
#  ...]

# %%
to_data_frame(facts)[['subject', 'object']]
# Out:
#           subject                     object
# 0           apple                      fruit
# 1         a fruit                     eating
# 2           fruit               good for you
# 3           fruit  a good source of vitamins
# 4           fruit            good for health
# 5       pineapple                      fruit
# 6           fruit                      eaten
# 7           fruit                     a tree
# 8         a fruit                   a market
# 9           grape                      fruit
# 10        produce                      fruit
# 11         orange                      fruit
# 12          lemon                      fruit
# 13           lime                      fruit
# 14        a mango                    a fruit
# 15          fruit  a better snack than candy
# 16          plums                      fruit
# 17     watermelon                    a fruit
# 18      raspberry                      fruit
# 19          peach                      fruit
# 20           seed                      fruit
# 21     membuahkan                      fruit
# 22           pome                      fruit
# 23         frutto                      fruit
# 24          fruit                       plod
# 25    ทำให้ออกลูก                      fruit
# 26             産物                      fruit
# 27             効果                      fruit
# 28              結                      fruit
# 29           wine                      fruit
# ...           ...                        ...
# 2387         wine                      fruit
# 2388    vegetable                      fruit
# 2389        fruit                      seeds
# 2390       nectar                      fruit
# 2391        fruit                 vegetables
# 2392        prune                      fruit
# 2393      filling                      fruit
# 2394         cake                      fruit
# 2395        fruit                     cherry
# 2396        fruit               cherry apple
# 2397        jelly                      fruit
# 2398          box                      fruit
# 2399        apply                      fruit
# 2400        fruit                 sweet food
# 2401        fruit                      sweet
# 2402        fruit                      group
# 2403        fruit                 food group
# 2404         corn                      fruit
# 2405        fruit                  vegetable
# 2406        fruit                    healthy
# 2407         core                      fruit
# 2408        flesh                      fruit
# 2409          bat                      fruit
# 2410        fruit                     veggie
# 2411        fruit                 vegetables
# 2412        fruit                  vegetable
# 2413         grow                      fruit
# 2414        fruit                     apples
# 2415        fruit             apples oranges
# 2416        fruit                    oranges
#
# [2417 rows x 2 columns]
